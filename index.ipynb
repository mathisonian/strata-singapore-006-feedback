# %%
from pyspark import SparkContext
sc = SparkContext(master='spark://master:7077')

# %%
from pyspark.mllib.clustering import KMeans, KMeansModel

# %%
from lightning import Lightning

# %%
lgn = Lightning(host="http://public.lightning-viz.org", ipython=True)
# Out:
# <div style='margin-top:8px'><img src='data:image/png;base64,...' width='30px' height='35px' style='display: inline-block; padding-right: 10px'></img><span>Lightning initialized</span></div>
# Connected to server at http://public.lightning-viz.org

# %%
from skimage import io

# %%
image = io.imread('http://earthexplorer.usgs.gov/browse/landsat_8/2015/125/059/LC81250592015248LGN00.jpg')

# %%
viz = lgn.imagepoly(image)
viz
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://public.lightning-viz.org/css/app.css"/><link rel="stylesheet" href="http://public.lightning-viz.org/css/dynamic/viz/?visualizations[]=image-poly"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="980dd05a-b768-42e9-aef2-6f99ca623c9b" class="feed-item-container"><div data-type="lightning-image-poly" data-data="{}" data-images="[&quot;https://s3.amazonaws.com/i.gif.fm/sessions/1ff9dd0a-0bd1-4ead-bc8d-0e0cb9eb7e4a/A12oidBDB35w600BZCKKw8mQLnzfNWGm&quot;]" data-options="{&quot;width&quot;:600,&quot;description&quot;:null,&quot;height&quot;:null}" id="viz-980dd05a-b768-42e9-aef2-6f99ca62
# ...

# %%
viz.polygons()
# Out:
# [[[551.1, 647.9599999999999],
#   [544.8375000000001, 681.7774999999999],
#   [543.1675, 695.555],
#   [543.1675, 726.8675],
#   [551.1, 647.9599999999999]],
#  [[554.8575000000001, 683.4475],
#   [556.945, 688.4575],
#   [560.7025000000001, 693.4675],
#   [564.46, 695.9725],
#   [571.1400000000001, 698.4775],
#   [577.82, 698.4775],
#   [592.0150000000001, 695.1374999999999],
#   [605.7925, 689.7099999999999],
#   [608.2975, 685.9525],
#   [607.8800000000001, 681.7774999999999],
#   [604.9575000000001, 677.6025],
#   [599.9475000000001, 672.5925],
#   [579.0725000000001, 660.9024999999999],
#   [561.955, 655.475],
#   [554.44, 663.8249999999999],
#   [554.0225, 678.02],
#   [554.8575000000001, 683.4475]],
#  [[516.865, 604.1225],
#   [523.9625000000001, 609.1324999999999],
#   [531.4775000000001, 612.055],
#   [550.6825, 617.0649999999999],
#   [573.6450000000001, 617.0649999999999],
#   [583.2475000000001, 616.23],
#   [584.5, 614.1424999999999],
#   [584.5, 609.9675],
# ...

# %%
viz.points()
# Out:
# [[[544, 681],
#   [544, 682],
#   [544, 683],
#   [544, 684],
#   [544, 685],
#   [544, 686],
#   [544, 687],
#   [544, 688],
#   [544, 689],
#   [544, 690],
#   [544, 691],
#   [544, 692],
#   [544, 693],
#   [544, 694],
#   [544, 695],
#   [544, 696],
#   [544, 697],
#   [544, 698],
#   [544, 699],
#   [544, 700],
#   [544, 701],
#   [544, 702],
#   [544, 703],
#   [544, 704],
#   [544, 705],
#   [544, 706],
#   [544, 707],
#   [544, 708],
#   [544, 709],
#   [544, 710],
#   [544, 711],
#   [544, 712],
#   [544, 713],
#   [544, 714],
#   [544, 715],
#   [544, 716],
#   [545, 677],
#   [545, 678],
#   [545, 679],
#   [545, 680],
#   [545, 681],
#   [545, 682],
#   [545, 683],
#   [545, 684],
#   [545, 685],
#   [545, 686],
#   [545, 687],
#   [545, 688],
#   [545, 689],
#   [545, 690],
#   [545, 691],
#   [545, 692],
#   [545, 693],
#   [545, 694],
#   [545, 695],
#   [545, 696],
#   [545, 697],
#   [545, 698],
#   [545, 699],
#   [545, 700],
#   [545, 701],
#   [545, 702],
# ...

# %%
# exercise 1 

calculate the average color of each
